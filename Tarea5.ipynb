# %% [markdown]
# # TAREA 5

# %% [markdown]
# ## Leer Datos

# %% [markdown]
# Primero se leen y se preparan los datos:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
archivo = "/content/todos_datos_2.xlsx"

data= pd.read_excel(archivo)

data.pop("EMISIONES(sin 3B y 3D)(Gg en CO2e)")
data
# Out:
#        Año     Categoria                                             Fuente  \
# 0     1990   [1] Energía          [1A] Actividades de quema del combustible
# 1     1990   [1] Energía          [1A] Actividades de quema del combustible
# 2     1990   [1] Energía          [1A] Actividades de quema del combustible
# 3     1990   [1] Energía          [1A] Actividades de quema del combustible
# 4     1990   [1] Energía          [1A] Actividades de quema del combustible
# ...    ...           ...                                                ...
# 4123  2021  [4] Residuos  [4C] Incineración y quema a cielo abierto  de ...
# 4124  2021  [4] Residuos  [4C] Incineración y quema a cielo abierto  de ...
# 4125  2021  [4] Residuos  [4D] Tratamiento y eliminación de aguas residu...
# 4126  2021  [4] Residuos  [4D] Tratamiento y eliminación de aguas residu...
# 4127  2021  [4] Residuos                                         [4E] Otros
#
#                                              Subfuente1  \
# 0                        [1A1] Industrias de la energía
# 1                        [1A1] Industrias de la energía
# 2                        [1A1] Industrias de la energía
# 3     [1A2] Industrias manufactura y de la construcción
# 4     [1A2] Industrias manufactura y de la construcción
# ...                                                 ...
# 4123  [4C1] Incineración de residuos peligrosos indu...
# 4124    [4C2] Quema a cielo abierto de residuos sólidos
# 4125  [4D1] Tratamiento y eliminación de aguas resid...
# 4126  [4D2] Tratamiento y eliminación de aguas resid...
# 4127                                                  -
#
#                                              Subfuente2 Subfuente3  \
# 0     [1A1a] Actividad principal producción de elect...          -
# 1                        [1A1b] Refinación del petróleo          -
# 2     [1A1c] Manufactura de combustibles sólidos y o...          -
# 3                                 [1A2a] Hierro y acero          -
# 4                            [1A2b] Metales no ferrosos          -
# ...                                                 ...        ...
# 4123                                                  -          -
# 4124                                                  -          -
# 4125                                                  -          -
# 4126                                                  -          -
# 4127                                                  -          -
#
#                CO2           CH4          N2O  HFCs  PFCs  NF3  SF6  \
# 0     70302.750576     62.745182   139.850236   NaN   NaN  NaN  NaN
# 1     11550.924752     11.131438    20.203821   NaN   NaN  NaN  NaN
# 2     25911.446413     18.174816    27.485844   NaN   NaN  NaN  NaN
# 3      5050.957286      3.683582     5.648170   NaN   NaN  NaN  NaN
# 4      2105.775916      1.876280     2.920578   NaN   NaN  NaN  NaN
# ...            ...           ...          ...   ...   ...  ...  ...
# 4123     28.597444      0.041421     0.762761   NaN   NaN  NaN  NaN
# 4124   1705.641772    754.454674   164.777875   NaN   NaN  NaN  NaN
# 4125           NaN   4930.620916  2781.021175   NaN   NaN  NaN  NaN
# 4126           NaN  20874.261433  2790.491065   NaN   NaN  NaN  NaN
# 4127           NaN           NaN          NaN   NaN   NaN  NaN  NaN
#
#       EMISIONES_NETAS(Gg en CO2e)  Carbono_negro(Gg)
# 0                    70505.345994          11.656345
# 1                    11582.260011           2.190852
# 2                    25957.107072           0.305281
# 3                     5060.289038           0.122834
# 4                     2110.572775           0.038763
# ...                           ...                ...
# 4123                    29.401625                NaN
# 4124                  2624.874321           1.435000
# 4125                  7711.642091                NaN
# 4126                 23664.752498                NaN
# 4127                     0.000000                NaN
#
# [4128 rows x 15 columns]

# %% [markdown]
# ## K medias

# %% [markdown]
# El método más utilizado en la bibliografía es el de K medias. Se importan las librerías necesarias:

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Rellenamos los nan con cero indicando una emisión nula:

# %%
data_num_ceros= data.copy()

for i in range(0,len(data_num_ceros.iloc[:,1])):
  for j in range(6,len(data_num_ceros.columns)):
    #aux = data_num_ceros.iloc[i,j].item()
    if np.isnan(data_num_ceros.iloc[i,j]) == True:
      data_num_ceros.iloc[i,j] = 0


data_num_ceros
# Out:
#        Año     Categoria                                             Fuente  \
# 0     1990   [1] Energía          [1A] Actividades de quema del combustible
# 1     1990   [1] Energía          [1A] Actividades de quema del combustible
# 2     1990   [1] Energía          [1A] Actividades de quema del combustible
# 3     1990   [1] Energía          [1A] Actividades de quema del combustible
# 4     1990   [1] Energía          [1A] Actividades de quema del combustible
# ...    ...           ...                                                ...
# 4123  2021  [4] Residuos  [4C] Incineración y quema a cielo abierto  de ...
# 4124  2021  [4] Residuos  [4C] Incineración y quema a cielo abierto  de ...
# 4125  2021  [4] Residuos  [4D] Tratamiento y eliminación de aguas residu...
# 4126  2021  [4] Residuos  [4D] Tratamiento y eliminación de aguas residu...
# 4127  2021  [4] Residuos                                         [4E] Otros
#
#                                              Subfuente1  \
# 0                        [1A1] Industrias de la energía
# 1                        [1A1] Industrias de la energía
# 2                        [1A1] Industrias de la energía
# 3     [1A2] Industrias manufactura y de la construcción
# 4     [1A2] Industrias manufactura y de la construcción
# ...                                                 ...
# 4123  [4C1] Incineración de residuos peligrosos indu...
# 4124    [4C2] Quema a cielo abierto de residuos sólidos
# 4125  [4D1] Tratamiento y eliminación de aguas resid...
# 4126  [4D2] Tratamiento y eliminación de aguas resid...
# 4127                                                  -
#
#                                              Subfuente2 Subfuente3  \
# 0     [1A1a] Actividad principal producción de elect...          -
# 1                        [1A1b] Refinación del petróleo          -
# 2     [1A1c] Manufactura de combustibles sólidos y o...          -
# 3                                 [1A2a] Hierro y acero          -
# 4                            [1A2b] Metales no ferrosos          -
# ...                                                 ...        ...
# 4123                                                  -          -
# 4124                                                  -          -
# 4125                                                  -          -
# 4126                                                  -          -
# 4127                                                  -          -
#
#                CO2           CH4          N2O  HFCs  PFCs  NF3  SF6  \
# 0     70302.750576     62.745182   139.850236   0.0   0.0  0.0  0.0
# 1     11550.924752     11.131438    20.203821   0.0   0.0  0.0  0.0
# 2     25911.446413     18.174816    27.485844   0.0   0.0  0.0  0.0
# 3      5050.957286      3.683582     5.648170   0.0   0.0  0.0  0.0
# 4      2105.775916      1.876280     2.920578   0.0   0.0  0.0  0.0
# ...            ...           ...          ...   ...   ...  ...  ...
# 4123     28.597444      0.041421     0.762761   0.0   0.0  0.0  0.0
# 4124   1705.641772    754.454674   164.777875   0.0   0.0  0.0  0.0
# 4125      0.000000   4930.620916  2781.021175   0.0   0.0  0.0  0.0
# 4126      0.000000  20874.261433  2790.491065   0.0   0.0  0.0  0.0
# 4127      0.000000      0.000000     0.000000   0.0   0.0  0.0  0.0
#
#       EMISIONES_NETAS(Gg en CO2e)  Carbono_negro(Gg)
# 0                    70505.345994          11.656345
# 1                    11582.260011           2.190852
# 2                    25957.107072           0.305281
# 3                     5060.289038           0.122834
# 4                     2110.572775           0.038763
# ...                           ...                ...
# 4123                    29.401625           0.000000
# 4124                  2624.874321           1.435000
# 4125                  7711.642091           0.000000
# 4126                 23664.752498           0.000000
# 4127                     0.000000           0.000000
#
# [4128 rows x 15 columns]

# %% [markdown]
# Al igual que en la mayoría de la bibliografía se estandarizan los datos:

# %%
scaler = StandardScaler()

# %%
data_var = data_num_ceros.iloc[:,6:14]
scaled = scaler.fit_transform(data_var)
# https://datatofish.com/numpy-array-to-pandas-dataframe/
data_scaled = pd.DataFrame(scaled, columns = data_var.columns)
data_scaled
# Out:
#            CO2       CH4       N2O      HFCs      PFCs       NF3       SF6  \
# 0     3.209415 -0.171427 -0.090804 -0.076036 -0.055099 -0.072371 -0.072369
# 1     0.429085 -0.179315 -0.177186 -0.076036 -0.055099 -0.072371 -0.072369
# 2     1.108672 -0.178239 -0.171928 -0.076036 -0.055099 -0.072371 -0.072369
# 3     0.121485 -0.180453 -0.187695 -0.076036 -0.055099 -0.072371 -0.072369
# 4    -0.017891 -0.180729 -0.189664 -0.076036 -0.055099 -0.072371 -0.072369
# ...        ...       ...       ...       ...       ...       ...       ...
# 4123 -0.116190 -0.181010 -0.191222 -0.076036 -0.055099 -0.072371 -0.072369
# 4124 -0.036827 -0.065719 -0.072807 -0.076036 -0.055099 -0.072371 -0.072369
# 4125 -0.117543  0.572487  1.816060 -0.076036 -0.055099 -0.072371 -0.072369
# 4126 -0.117543  3.009011  1.822897 -0.076036 -0.055099 -0.072371 -0.072369
# 4127 -0.117543 -0.181016 -0.191772 -0.076036 -0.055099 -0.072371 -0.072369
#
#       EMISIONES_NETAS(Gg en CO2e)
# 0                        2.992439
# 1                        0.341113
# 2                        0.987929
# 3                        0.047648
# 4                       -0.085079
# ...                           ...
# 4123                    -0.178724
# 4124                    -0.061937
# 4125                     0.166949
# 4126                     0.884782
# 4127                    -0.180047
#
# [4128 rows x 8 columns]

# %% [markdown]
# ### Elección de número de clusters

# %% [markdown]
# Usamos el método del codo:

# %% [markdown]
# Se crea una función para facilitar el calculo de la inercia

# %%
def f_kmeans(n_clusters):
    kmeans = KMeans(n_clusters = n_clusters, n_init = 'auto').fit(data_scaled)
    return kmeans.inertia_ / n_clusters

# %% [markdown]
# Se calcula la inercia para los posibles números de clusters y se guardan en una lista:

# %%
inertia = []
for i in range(2,9):
  inertia.append(f_kmeans(i))

# %% [markdown]
# Se pasa a un dataframe para facilitar su visualización:

# %%
df_inertias = pd.DataFrame({'n_clusters': range(2, 9), 'inertia': inertia})
df_inertias
# Out:
#    n_clusters       inertia
# 0           2  14431.329540
# 1           3   8458.705637
# 2           4   5326.324875
# 3           5   3487.297848
# 4           6   2423.944236
# 5           7   1612.986222
# 6           8   1001.432431

# %% [markdown]
# Graficamos:

# %%
plt.figure()
plt.plot(df_inertias.n_clusters, df_inertias.inertia)
plt.xlabel('Número de grupos')
plt.ylabel('Media de las distancias cuadradas entre grupos')
plt.ylim((0, 1.1 * df_inertias.inertia.max()))
plt.xticks(range(2, 9))
plt.show()

# %% [markdown]
# Parece se que lo mejor es conservar 4 clusters.
#
# Comprobando:

# %%
from numpy import ones,vstack
from numpy.linalg import lstsq
points = [
    (df_inertias.iloc[0, :].n_clusters, df_inertias.iloc[0, :].inertia),
    (df_inertias.iloc[-1, :].n_clusters, df_inertias.iloc[-1, :].inertia)
]
x_coords, y_coords = zip(*points)
A = vstack([x_coords, ones(len(x_coords))]).T
m, b = lstsq(A, y_coords, rcond=None)[0]

# %%
plt.figure()
plt.plot(df_inertias.n_clusters, df_inertias.inertia)
plt.plot(df_inertias.iloc[[0, -1], :].n_clusters, df_inertias.iloc[[0, -1], :].inertia, c='r')
for i, r in df_inertias.iterrows():
    d = '$d_{' + str(i) + '}' + f' = {abs(round(r.inertia - (m * r.n_clusters + b), 2)):,}$'
    plt.annotate(d, xytext=(r.n_clusters, m * r.n_clusters + b), xy=(r.n_clusters, m * r.n_clusters + b), rotation = 45)
    plt.plot([r.n_clusters, r.n_clusters], [r.inertia, m * r.n_clusters + b], '--k')
plt.xlabel('Número de grupos')
plt.ylabel('Media de las distancias cuadradas entre grupos')
plt.xlim((1.5, 9.5))
plt.ylim((0, 1.15 * df_inertias.inertia.max()))
plt.xticks(range(2, 10))
plt.show()

# %% [markdown]
# Se elige usar 4 clusters:

# %%
kmeans = KMeans(n_clusters = 4, n_init = 'auto').fit(data_scaled)

# %%
kmeans.labels_
# Out:
# array([2, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
df_centroids_freq = pd.DataFrame(np.unique(kmeans.labels_, return_counts = True)).T
df_centroids_freq.columns = ['ck', 'nk']
df_centroids_freq
# Out:
#    ck    nk
# 0   0  4022
# 1   1    32
# 2   2    64
# 3   3    10

# %% [markdown]
# Podemos imprimir los centros:

# %%
kmeans.cluster_centers_
# Out:
# array([[-9.06981856e-02, -8.22350122e-02, -8.85545756e-03,
#          2.00392942e-03, -4.68501205e-02,  1.90733998e-03,
#          1.90728410e-03, -1.10968950e-01],
#        [-1.17543185e-01,  1.06738729e+01, -1.91772448e-01,
#         -7.60358880e-02, -5.50994051e-02, -7.23709567e-02,
#         -7.23688365e-02,  3.01604879e+00],
#        [ 5.77623844e+00, -1.40696163e-01,  6.82360830e-01,
#         -7.60358880e-02, -5.50994051e-02, -7.23709567e-02,
#         -7.23688365e-02,  5.49028603e+00],
#        [-1.12977573e-01, -1.81016059e-01, -1.91772448e-01,
#         -7.60358880e-02,  1.93720727e+01, -7.23709567e-02,
#         -7.23688365e-02, -1.57475077e-01]])

# %%
df_centers = pd.DataFrame(kmeans.cluster_centers_, columns = ['x','y','z','w','v','u','r','s'])
df_centers
# Out:
#           x          y         z         w          v         u         r  \
# 0 -0.090698  -0.082235 -0.008855  0.002004  -0.046850  0.001907  0.001907
# 1 -0.117543  10.673873 -0.191772 -0.076036  -0.055099 -0.072371 -0.072369
# 2  5.776238  -0.140696  0.682361 -0.076036  -0.055099 -0.072371 -0.072369
# 3 -0.112978  -0.181016 -0.191772 -0.076036  19.372073 -0.072371 -0.072369
#
#           s
# 0 -0.110969
# 1  3.016049
# 2  5.490286
# 3 -0.157475

# %% [markdown]
# Se grafican algunas caras:

# %%
plt.figure()
plt.scatter(
    data_scaled.CO2,
    data_scaled.CH4,
    s = 1, # tamaño de los marcadores
    c = kmeans.labels_
)
plt.scatter(df_centers.x, df_centers.y, s=10, c='k')
plt.show()

# %%
plt.figure()
plt.scatter(
    data_scaled.HFCs,
    data_scaled.PFCs,
    s = 1, # tamaño de los marcadores
    c = kmeans.labels_
)
plt.scatter(df_centers.x, df_centers.y, s=10, c='k')
plt.show()

# %%
plt.figure()
plt.scatter(
    data_scaled.N2O,
    data_scaled.NF3,
    s = 1, # tamaño de los marcadores
    c = kmeans.labels_
)
plt.scatter(df_centers.x, df_centers.y, s=10, c='k')
plt.show()

# %% [markdown]
# ## Otro algoritmo no supervisado

# %% [markdown]
# ## Bibliografía

# %% [markdown]
# * https://zenodo.org/records/1228469
# * http://sedici.unlp.edu.ar/handle/10915/71114
# * https://www.mdpi.com/2077-0472/13/7/1354
# * https://www.sciencedirect.com/science/article/pii/S1309104215305754
# * https://www.sciencedirect.com/science/article/abs/pii/S037842902300014X (nearest neighbor)
