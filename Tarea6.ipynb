# %% [markdown]
# # TAREA 6

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
archivo = "/content/todos_datos_2.xlsx"

data= pd.read_excel(archivo)

data.pop("EMISIONES(sin 3B y 3D)(Gg en CO2e)")
data
# Out:
#        Año     Categoria                                             Fuente  \
# 0     1990   [1] Energía          [1A] Actividades de quema del combustible
# 1     1990   [1] Energía          [1A] Actividades de quema del combustible
# 2     1990   [1] Energía          [1A] Actividades de quema del combustible
# 3     1990   [1] Energía          [1A] Actividades de quema del combustible
# 4     1990   [1] Energía          [1A] Actividades de quema del combustible
# ...    ...           ...                                                ...
# 4123  2021  [4] Residuos  [4C] Incineración y quema a cielo abierto  de ...
# 4124  2021  [4] Residuos  [4C] Incineración y quema a cielo abierto  de ...
# 4125  2021  [4] Residuos  [4D] Tratamiento y eliminación de aguas residu...
# 4126  2021  [4] Residuos  [4D] Tratamiento y eliminación de aguas residu...
# 4127  2021  [4] Residuos                                         [4E] Otros
#
#                                              Subfuente1  \
# 0                        [1A1] Industrias de la energía
# 1                        [1A1] Industrias de la energía
# 2                        [1A1] Industrias de la energía
# 3     [1A2] Industrias manufactura y de la construcción
# 4     [1A2] Industrias manufactura y de la construcción
# ...                                                 ...
# 4123  [4C1] Incineración de residuos peligrosos indu...
# 4124    [4C2] Quema a cielo abierto de residuos sólidos
# 4125  [4D1] Tratamiento y eliminación de aguas resid...
# 4126  [4D2] Tratamiento y eliminación de aguas resid...
# 4127                                                  -
#
#                                              Subfuente2 Subfuente3  \
# 0     [1A1a] Actividad principal producción de elect...          -
# 1                        [1A1b] Refinación del petróleo          -
# 2     [1A1c] Manufactura de combustibles sólidos y o...          -
# 3                                 [1A2a] Hierro y acero          -
# 4                            [1A2b] Metales no ferrosos          -
# ...                                                 ...        ...
# 4123                                                  -          -
# 4124                                                  -          -
# 4125                                                  -          -
# 4126                                                  -          -
# 4127                                                  -          -
#
#                CO2           CH4          N2O  HFCs  PFCs  NF3  SF6  \
# 0     70302.750576     62.745182   139.850236   NaN   NaN  NaN  NaN
# 1     11550.924752     11.131438    20.203821   NaN   NaN  NaN  NaN
# 2     25911.446413     18.174816    27.485844   NaN   NaN  NaN  NaN
# 3      5050.957286      3.683582     5.648170   NaN   NaN  NaN  NaN
# 4      2105.775916      1.876280     2.920578   NaN   NaN  NaN  NaN
# ...            ...           ...          ...   ...   ...  ...  ...
# 4123     28.597444      0.041421     0.762761   NaN   NaN  NaN  NaN
# 4124   1705.641772    754.454674   164.777875   NaN   NaN  NaN  NaN
# 4125           NaN   4930.620916  2781.021175   NaN   NaN  NaN  NaN
# 4126           NaN  20874.261433  2790.491065   NaN   NaN  NaN  NaN
# 4127           NaN           NaN          NaN   NaN   NaN  NaN  NaN
#
#       EMISIONES_NETAS(Gg en CO2e)  Carbono_negro(Gg)
# 0                    70505.345994          11.656345
# 1                    11582.260011           2.190852
# 2                    25957.107072           0.305281
# 3                     5060.289038           0.122834
# 4                     2110.572775           0.038763
# ...                           ...                ...
# 4123                    29.401625                NaN
# 4124                  2624.874321           1.435000
# 4125                  7711.642091                NaN
# 4126                 23664.752498                NaN
# 4127                     0.000000                NaN
#
# [4128 rows x 15 columns]

# %%
for i in range(0,len(data.iloc[:,1])):
  for j in range(6,len(data.columns)):
    #aux = data_num_ceros.iloc[i,j].item()
    if np.isnan(data.iloc[i,j]) == True:
      data.iloc[i,j] = 0


data
# Out:
#        Año     Categoria                                             Fuente  \
# 0     1990   [1] Energía          [1A] Actividades de quema del combustible
# 1     1990   [1] Energía          [1A] Actividades de quema del combustible
# 2     1990   [1] Energía          [1A] Actividades de quema del combustible
# 3     1990   [1] Energía          [1A] Actividades de quema del combustible
# 4     1990   [1] Energía          [1A] Actividades de quema del combustible
# ...    ...           ...                                                ...
# 4123  2021  [4] Residuos  [4C] Incineración y quema a cielo abierto  de ...
# 4124  2021  [4] Residuos  [4C] Incineración y quema a cielo abierto  de ...
# 4125  2021  [4] Residuos  [4D] Tratamiento y eliminación de aguas residu...
# 4126  2021  [4] Residuos  [4D] Tratamiento y eliminación de aguas residu...
# 4127  2021  [4] Residuos                                         [4E] Otros
#
#                                              Subfuente1  \
# 0                        [1A1] Industrias de la energía
# 1                        [1A1] Industrias de la energía
# 2                        [1A1] Industrias de la energía
# 3     [1A2] Industrias manufactura y de la construcción
# 4     [1A2] Industrias manufactura y de la construcción
# ...                                                 ...
# 4123  [4C1] Incineración de residuos peligrosos indu...
# 4124    [4C2] Quema a cielo abierto de residuos sólidos
# 4125  [4D1] Tratamiento y eliminación de aguas resid...
# 4126  [4D2] Tratamiento y eliminación de aguas resid...
# 4127                                                  -
#
#                                              Subfuente2 Subfuente3  \
# 0     [1A1a] Actividad principal producción de elect...          -
# 1                        [1A1b] Refinación del petróleo          -
# 2     [1A1c] Manufactura de combustibles sólidos y o...          -
# 3                                 [1A2a] Hierro y acero          -
# 4                            [1A2b] Metales no ferrosos          -
# ...                                                 ...        ...
# 4123                                                  -          -
# 4124                                                  -          -
# 4125                                                  -          -
# 4126                                                  -          -
# 4127                                                  -          -
#
#                CO2           CH4          N2O  HFCs  PFCs  NF3  SF6  \
# 0     70302.750576     62.745182   139.850236   0.0   0.0  0.0  0.0
# 1     11550.924752     11.131438    20.203821   0.0   0.0  0.0  0.0
# 2     25911.446413     18.174816    27.485844   0.0   0.0  0.0  0.0
# 3      5050.957286      3.683582     5.648170   0.0   0.0  0.0  0.0
# 4      2105.775916      1.876280     2.920578   0.0   0.0  0.0  0.0
# ...            ...           ...          ...   ...   ...  ...  ...
# 4123     28.597444      0.041421     0.762761   0.0   0.0  0.0  0.0
# 4124   1705.641772    754.454674   164.777875   0.0   0.0  0.0  0.0
# 4125      0.000000   4930.620916  2781.021175   0.0   0.0  0.0  0.0
# 4126      0.000000  20874.261433  2790.491065   0.0   0.0  0.0  0.0
# 4127      0.000000      0.000000     0.000000   0.0   0.0  0.0  0.0
#
#       EMISIONES_NETAS(Gg en CO2e)  Carbono_negro(Gg)
# 0                    70505.345994          11.656345
# 1                    11582.260011           2.190852
# 2                    25957.107072           0.305281
# 3                     5060.289038           0.122834
# 4                     2110.572775           0.038763
# ...                           ...                ...
# 4123                    29.401625           0.000000
# 4124                  2624.874321           1.435000
# 4125                  7711.642091           0.000000
# 4126                 23664.752498           0.000000
# 4127                     0.000000           0.000000
#
# [4128 rows x 15 columns]

# %%
data2 = data.copy()
data2 = data2.drop(['Fuente',	'Subfuente1',	'Subfuente2',	'Subfuente3'], axis = 1)
data2['Actividad'] = data.Categoria.str.cat([data.Fuente,data.Subfuente1,data.Subfuente2,data.Subfuente3], sep=",")
data2 = data2.reindex(columns=["Año","Actividad","CO2","CH4","N2O","HFCs","PFCs","NF3","SF6","EMISIONES_NETAS(Gg en CO2e)"])
data2.columns = ["Year","Actividad","CO2","CH4","N2O","HFCs","PFCs","NF3","SF6","EMISIONES"]
data2=data2.sort_values(['Actividad', 'Year'], ignore_index=True)
data2
# Out:
#       Year                                          Actividad           CO2  \
# 0     1990  [1] Energía,[1A] Actividades de quema del comb...  70302.750576
# 1     1991  [1] Energía,[1A] Actividades de quema del comb...  72650.041217
# 2     1992  [1] Energía,[1A] Actividades de quema del comb...  71170.899123
# 3     1993  [1] Energía,[1A] Actividades de quema del comb...  73045.097563
# 4     1994  [1] Energía,[1A] Actividades de quema del comb...  87788.813716
# ...    ...                                                ...           ...
# 4123  2017                      [4] Residuos,[4E] Otros,-,-,-      0.000000
# 4124  2018                      [4] Residuos,[4E] Otros,-,-,-      0.000000
# 4125  2019                      [4] Residuos,[4E] Otros,-,-,-      0.000000
# 4126  2020                      [4] Residuos,[4E] Otros,-,-,-      0.000000
# 4127  2021                      [4] Residuos,[4E] Otros,-,-,-      0.000000
#
#             CH4         N2O  HFCs  PFCs  NF3  SF6     EMISIONES
# 0     62.745182  139.850236   0.0   0.0  0.0  0.0  70505.345994
# 1     64.183908  142.699466   0.0   0.0  0.0  0.0  72856.924591
# 2     62.725316  141.218844   0.0   0.0  0.0  0.0  71374.843282
# 3     63.421282  150.285020   0.0   0.0  0.0  0.0  73258.803865
# 4     75.804244  181.142773   0.0   0.0  0.0  0.0  88045.760733
# ...         ...         ...   ...   ...  ...  ...           ...
# 4123   0.000000    0.000000   0.0   0.0  0.0  0.0      0.000000
# 4124   0.000000    0.000000   0.0   0.0  0.0  0.0      0.000000
# 4125   0.000000    0.000000   0.0   0.0  0.0  0.0      0.000000
# 4126   0.000000    0.000000   0.0   0.0  0.0  0.0      0.000000
# 4127   0.000000    0.000000   0.0   0.0  0.0  0.0      0.000000
#
# [4128 rows x 10 columns]

# %%
data3 = data2.copy()
data3 = data3.groupby('Year', as_index= False).sum()
data3
# Out:
# <ipython-input-13-918f6107fcde>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data3 = data3.groupby('Year', as_index= False).sum()
#     Year            CO2            CH4           N2O          HFCs  \
# 0   1990  319999.845468  117840.420104  28347.091322    760.635840
# 1   1991  329716.352947  119392.866646  27177.033416    882.870080
# 2   1992  333049.711742  117998.461485  27988.131341    566.392320
# 3   1993  338075.107083  118275.355130  26219.010959    869.860000
# 4   1994  360853.347717  124026.181041  28335.696072    695.282880
# 5   1995  347496.645362  127038.456514  28258.992994    647.780960
# 6   1996  359553.271302  131254.597198  27629.111442   1632.008640
# 7   1997  375317.236154  138365.118856  29935.230414   1668.588144
# 8   1998  393944.486930  143331.786279  30056.780951   1312.214313
# 9   1999  386967.007049  136486.778859  31511.027511   1809.667268
# 10  2000  195440.705177  139956.673237  31982.242922   1903.556308
# 11  2001  197460.694789  140413.078160  31193.867587   1750.124037
# 12  2002  229882.008120  143348.719564  31902.016963   2481.543096
# 13  2003  224329.118084  145781.654476  32541.263745   2795.150914
# 14  2004  238241.811546  144473.810899  34071.647222   3730.521174
# 15  2005  253144.378382  147152.584060  32198.640079   4402.758309
# 16  2006  262024.905957  151651.166696  31918.170332   3473.339603
# 17  2007  289366.123478  161204.327143  33870.670124   7283.639972
# 18  2008  313910.934717  180349.047913  35691.536922   8396.057027
# 19  2009  320049.421894  177993.314319  34340.820640   9706.171951
# 20  2010  310682.773874  168300.249419  40108.018199  11850.052360
# 21  2011  331790.513682  168480.162242  40920.947781  12644.608377
# 22  2012  325051.509939  160183.734406  38281.439498  12930.716781
# 23  2013  324012.192544  163464.872225  45831.028244  15148.655523
# 24  2014  326893.536596  168613.855890  40075.084241  17740.160138
# 25  2015  323593.447249  168025.655222  42953.349043  17607.017987
# 26  2016  370858.747966  174362.997822  36897.138130  18038.535549
# 27  2017  323275.764440  170958.541833  38627.529317  19232.310571
# 28  2018  332067.785561  173705.911917  42778.196744  21015.316210
# 29  2019  295777.936009  175558.468175  41190.822329  21731.809293
# 30  2020  464170.571806  193571.274851  37336.746306  21574.202701
# 31  2021  456265.876441  198041.614510  36315.629130  23386.370247
#
#           PFCs       NF3         SF6      EMISIONES
# 0   437.732260  0.000000   36.517125  467422.242118
# 1   320.770276  0.000000   39.035765  477528.929130
# 2   283.559069  0.000000   43.436972  479929.692930
# 3   173.181950  0.000000   47.776482  483660.291603
# 4     0.000000  0.000000   51.492871  513962.000582
# 5    69.967550  0.000000   53.408253  503565.251632
# 6   412.682896  0.000000   62.732709  520544.404187
# 7   445.862553  0.000000   65.246114  545797.282235
# 8   452.626555  0.045010   66.591703  569164.531740
# 9   522.157567  0.217059   68.657534  557365.512847
# 10  569.200795  0.389109   72.047886  369924.815434
# 11  346.989700  0.561159   76.082707  371241.398139
# 12  263.289828  0.733208   86.433303  407964.744083
# 13  169.511082  0.905258   97.370611  405714.974171
# 14    1.597234  0.945142  107.472358  420627.805575
# 15    1.664636  0.985027  114.306101  437015.316592
# 16    1.732038  1.024911  117.439653  449187.779190
# 17    1.799440  1.064795  137.070206  491864.695158
# 18    1.866841  1.104679  140.203759  538490.751858
# 19    1.934243  1.144563  140.893311  542233.700922
# 20    2.001645  1.184447  156.246864  531100.526809
# 21   18.433593  1.224332  161.515292  554017.405297
# 22   18.841220  1.264216  164.339720  536631.845780
# 23   19.400690  1.512604  177.916861  548655.578691
# 24   21.460383  1.674644  185.862464  553531.634354
# 25   23.641593  1.825557  200.840316  552405.776968
# 26   25.009730  1.967659  217.012247  600401.409103
# 27   25.233466  2.124616  257.088545  552378.592789
# 28   25.563248  2.272453  278.664096  569873.710230
# 29   26.173954  2.474452  400.915891  534688.600102
# 30   27.335247  2.424645    2.092453  716684.648009
# 31   32.310546  2.964630    2.498574  714047.264077

# %%
plt.figure()
plt.plot(data3.Year,data3.EMISIONES)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, StackingRegressor
from sklearn.metrics import mean_squared_error as RMSE
from sklearn.metrics import mean_squared_error as r2_score
from sklearn.linear_model import LinearRegression, BayesianRidge, PoissonRegressor
from sklearn.neighbors import KNeighborsRegressor

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
import multiprocessing

# %%
n_jobs = multiprocessing.cpu_count() // 2
model = RandomForestRegressor(n_jobs = n_jobs)

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(data3)
datascaled = pd.DataFrame(scaled, columns = data3.columns)

# %%
df_train = datascaled.sample(frac = 0.7)
x_train = df_train[['Year','CO2',	'CH4', 'N2O',	'HFCs',	'PFCs',	'NF3',	'SF6']]
y_train = df_train[['EMISIONES']]

df_test = datascaled.drop(df_train.index)
x_test = df_test[['Year','CO2',	'CH4', 'N2O',	'HFCs',	'PFCs',	'NF3',	'SF6']]
y_test = df_test[['EMISIONES']]

# %%
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
RMSE(y_test, y_pred, squared = False)
# Out:
# <ipython-input-41-ee6c4ca40a32>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x_train,y_train)
# 0.2160913648910492

# %% [markdown]
# Analizando diversos modelos a la vez

# %%
from timeit import default_timer as timer
from tqdm import tqdm

# %%
def fit(x, y, reg_model = 'RF', n_components = 3, n_jobs = None):
    match reg_model:
        case 'BayesRidge':
            model = BayesianRidge()
        case 'Boosting':
            model = GradientBoostingRegressor()
        case 'LinearReg':
            model = LinearRegression(n_jobs = n_jobs)
        case 'RF':
            model = RandomForestRegressor(n_jobs = n_jobs)
        case 'KNN':
            model = KNeighborsRegressor(algorithm = 'auto')
        case 'StackingRegressor':
            #https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.StackingRegressor.html#sklearn.ensemble.StackingRegressor
            gb  = GradientBoostingRegressor()
            rf  = RandomForestRegressor(n_jobs = n_jobs)
            gb.fit(x, y)
            rf.fit(x, y)
            model = StackingRegressor([("gb",gb), ("rf",rf)], n_jobs = n_jobs)
    model.fit(x, y)
    return model

# %%
models_ed = ['RF', 'LinearReg', 'BayesRidge', 'Boosting', 'KNN', 'StackingRegressor']
n_jobs = multiprocessing.cpu_count() // 2
results_ed = {
        'model' : [],
        'value' : [],
        'time' : []
    }
for i in tqdm(range(10)):
      df_train = datascaled.sample(frac = 0.7)
      x_train = df_train[['Year','CO2',	'CH4', 'N2O',	'HFCs',	'PFCs',	'NF3',	'SF6']]
      y_train = df_train[['EMISIONES']]

      df_test = datascaled.drop(df_train.index)
      x_test = df_test[['Year','CO2',	'CH4', 'N2O',	'HFCs',	'PFCs',	'NF3',	'SF6']]
      y_test = df_test[['EMISIONES']]
      for m in models_ed:
          start = timer()
          model = fit(x_train, y_train.values.ravel(), m, n_jobs = n_jobs)
          end = timer()
          y_pred = model.predict(x_test)
          results_ed['model'].append(m)
          results_ed['value'].append(RMSE(y_test, y_pred, squared = False))
          results_ed['time'].append(end - start)


df_results_ed = pd.DataFrame(results_ed)
df_results_ed = df_results_ed.sort_values('value')
# Out:
# 100%|██████████| 10/10 [00:16<00:00,  1.63s/it]

# %%
df_results_ed
# Out:
#                 model         value      time
# 7           LinearReg  1.034691e-15  0.002368
# 37          LinearReg  1.079376e-15  0.002334
# 25          LinearReg  1.089773e-15  0.002364
# 49          LinearReg  1.152709e-15  0.002340
# 1           LinearReg  1.286015e-15  0.003432
# 55          LinearReg  1.429048e-15  0.003580
# 43          LinearReg  1.480188e-15  0.002249
# 31          LinearReg  1.918925e-15  0.002441
# 13          LinearReg  1.963420e-15  0.002486
# 19          LinearReg  2.302004e-15  0.002410
# 20         BayesRidge  7.942952e-08  0.002035
# 50         BayesRidge  1.340478e-07  0.001986
# 32         BayesRidge  1.546209e-07  0.002022
# 26         BayesRidge  1.759854e-07  0.002002
# 56         BayesRidge  1.969186e-07  0.002472
# 38         BayesRidge  2.907248e-07  0.002003
# 2          BayesRidge  3.135857e-07  0.005378
# 44         BayesRidge  3.839111e-07  0.001967
# 14         BayesRidge  4.191124e-07  0.002025
# 8          BayesRidge  4.568029e-07  0.001998
# 5   StackingRegressor  1.423930e-01  1.470679
# 21           Boosting  1.526921e-01  0.047342
# 27           Boosting  1.817283e-01  0.044042
# 51           Boosting  2.055003e-01  0.044698
# 53  StackingRegressor  2.079012e-01  1.192834
# 29  StackingRegressor  2.118833e-01  1.198606
# 11  StackingRegressor  2.131899e-01  1.195909
# 23  StackingRegressor  2.155913e-01  1.175624
# 33           Boosting  2.188619e-01  0.047121
# 30                 RF  2.207778e-01  0.137889
# 41  StackingRegressor  2.217162e-01  3.021365
# 18                 RF  2.341025e-01  0.123858
# 57           Boosting  2.366343e-01  0.044228
# 3            Boosting  2.380295e-01  0.081404
# 9            Boosting  2.399874e-01  0.046740
# 59  StackingRegressor  2.404306e-01  1.179515
# 24                 RF  2.551847e-01  0.123139
# 15           Boosting  2.745544e-01  0.043056
# 17  StackingRegressor  2.778206e-01  1.214300
# 54                 RF  2.791125e-01  0.116000
# 45           Boosting  3.146268e-01  0.047805
# 39           Boosting  3.210982e-01  0.043409
# 47  StackingRegressor  3.292241e-01  1.188712
# 48                 RF  3.389765e-01  0.126119
# 35  StackingRegressor  3.496110e-01  1.203488
# 12                 RF  3.517512e-01  0.124197
# 22                KNN  3.605437e-01  0.001618
# 58                KNN  3.704642e-01  0.001703
# 6                  RF  3.730307e-01  0.120973
# 28                KNN  3.748821e-01  0.001445
# 0                  RF  4.404790e-01  0.223409
# 42                 RF  4.540604e-01  0.176582
# 34                KNN  4.709749e-01  0.001488
# 36                 RF  5.056248e-01  0.120264
# 52                KNN  6.055632e-01  0.001447
# 10                KNN  6.454470e-01  0.001522
# 16                KNN  6.716046e-01  0.001468
# 4                 KNN  6.799295e-01  0.002664
# 40                KNN  7.017271e-01  0.001446
# 46                KNN  7.055612e-01  0.001500
